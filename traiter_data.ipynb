# %%
import pandas as pd
df_process = pd.read_csv("data/wealth_individual.csv",sep = ";")
df_mean_field = pd.read_csv("data/mean_field.csv",sep = ";")
liste_N = df_process.columns
df = pd.concat([df_process,df_mean_field],axis = 1)
for N in liste_N:
    print(N)
    print(sum(abs(df["Mean Field"]-df[N])))
# Out:
# 10
# 1.9931750328356115
# 50
# 1.964415406884278
# 100
# 1.9466688179716742
# 200
# 1.943637451490753
# 500
# 1.9563030817687759
# 1000
# 1.9673459951990186
# 5000
# 1.9794347860621633
# 100000
# 1.98915885669369

# %%
sum(list(df_mean_field["Mean Field"]))
# Out:
# 0.9999999999998307

# %%
N = 5000
df_process[df_process[str(N)]!=0][str(N)]
# Out:
# 0     0.7420
# 1     0.0310
# 5     0.0550
# 6     0.0540
# 7     0.0842
# 8     0.0028
# 9     0.0004
# 10    0.0022
# 11    0.0046
# 12    0.0090
# 13    0.0066
# 14    0.0056
# 15    0.0004
# 16    0.0002
# 17    0.0004
# 19    0.0010
# 20    0.0004
# 21    0.0002
# Name: 5000, dtype: float64
